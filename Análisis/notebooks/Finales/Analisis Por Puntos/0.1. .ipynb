# %% [markdown]
# ---
# # Explicacion de obtencion del DataSet inicial
# ---

# %%
from faker import Faker
import random
import csv
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("0.3. ventas_retail_1M.csv", encoding="utf-8")
df.head()
# Out:
#    id_transaccion id_producto              nombre_producto precio id_tienda  \
# 0               1          63                 Salsa Bufalo   23.1         6
# 1               2          32                          NaN   9.49         5
# 2               3          77         Cereal Choco Krispis  53.36         2
# 3               4          45  Mix de Nueces Member's Mark  88.14         7
# 4               5          42       Yoghurt Griego Yoplait  28.32         1
#
#   nombre_tienda categoria_tienda  ciudad       fecha
# 0   City Market          Premium  CANCUN  2025-10-27
# 1      Chedraui     Autoservicio  PUEBLA  2025-12-27
# 2    Sam's Club          Mayoreo  PUEBLA  2025-11-09
# 3      La Comer          Premium  CANCUN  2025-10-27
# 4       Walmart     Autoservicio     GDL  2025-09-03

# %% [markdown]
# ## Descripción del conjunto de datos
#
# El conjunto de datos está compuesto por **1,030,000 registros** y **9 columnas**, lo que indica un volumen considerable de información. Cada fila representa una transacción individual, identificada de manera única mediante la variable `id_transaccion`.
#
#
#
# En términos de calidad de los datos, se observa que algunas columnas presentan valores faltantes. En particular, las variables `nombre_producto`, `precio` y `ciudad` no cuentan con el total de registros completos, lo que indica la presencia de información incompleta dentro del dataset. Por otro lado, columnas como `id_producto`, `id_tienda`, `nombre_tienda` y `categoria_tienda` se encuentran completamente pobladas, lo que refleja consistencia en los identificadores y atributos de las tiendas.
#
# Finalmente, el uso de memoria del DataFrame es de aproximadamente **70.7 MB**, lo cual es acorde al tamaño del conjunto de datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030000 entries, 0 to 1029999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   id_transaccion    1030000 non-null  int64
#  1   id_producto       1030000 non-null  object
#  2   nombre_producto   1013293 non-null  object
#  3   precio            1013461 non-null  object
#  4   id_tienda         1030000 non-null  object
#  5   nombre_tienda     1030000 non-null  object
#  6   categoria_tienda  1030000 non-null  object
#  7   ciudad            1013246 non-null  object
#  8   fecha             1030000 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 70.7+ MB

# %% [markdown]
# ---
# ## Obtener los nombres de columna
# ---

# %% [markdown]
# Esto nos ayuda a identificar como froma de lista por si ocupamos hacer un mapeo de alguna columna especifica

# %%
df.columns
# Out:
# Index(['id_transaccion', 'id_producto', 'nombre_producto', 'precio',
#        'id_tienda', 'nombre_tienda', 'categoria_tienda', 'ciudad', 'fecha'],
#       dtype='object')

# %% [markdown]
# ## Al momento de poner el all nos muestra de todas y no de solo las numericas

# %%
df.describe(include='all')
# Out:
#         id_transaccion id_producto       nombre_producto   precio id_tienda  \
# count     1.030000e+06     1030000               1013293  1013461   1030000
# unique             NaN         400                  3323    44944        40
# top                NaN          15  Café Soluble Nescafé     15.3         6
# freq               NaN       10325                 10170      521    102240
# mean      5.150005e+05         NaN                   NaN      NaN       NaN
# std       2.973355e+05         NaN                   NaN      NaN       NaN
# min       1.000000e+00         NaN                   NaN      NaN       NaN
# 25%       2.575008e+05         NaN                   NaN      NaN       NaN
# 50%       5.150005e+05         NaN                   NaN      NaN       NaN
# 75%       7.725002e+05         NaN                   NaN      NaN       NaN
# max       1.030000e+06         NaN                   NaN      NaN       NaN
#
#        nombre_tienda categoria_tienda   ciudad       fecha
# count        1030000          1030000  1013246     1030000
# unique            40                5      708        1616
# top      City Market     Autoservicio     CDMX  2025-06-21
# freq          102254           307486   200074        2939
# mean             NaN              NaN      NaN         NaN
# std              NaN              NaN      NaN         NaN
# min              NaN              NaN      NaN         NaN
# 25%              NaN              NaN      NaN         NaN
# 50%              NaN              NaN      NaN         NaN
# 75%              NaN              NaN      NaN         NaN
# max              NaN              NaN      NaN         NaN

# %% [markdown]
# Ya que tenemos los datos principales observamos que la columna que nos molesta son las de los errores con tetxo asiq ue vemos los valores unicos

# %%
df.nunique()
# Out:
# id_transaccion      1030000
# id_producto             400
# nombre_producto        3323
# precio                44944
# id_tienda                40
# nombre_tienda            40
# categoria_tienda          5
# ciudad                  708
# fecha                  1616
# dtype: int64

# %% [markdown]
# ## Analizamos nuestro faker inicial

# %% [markdown]
# Vemos que en ciudad solo deberiamos tener pocos unicos y vemos 708, asi como en id producto solo debemos tener 100 y tenemos 400

# %%
list(df['ciudad'].dropna().unique())
# Out:
# ['CANCUN',
#  'PUEBLA',
#  'GDL',
#  'CDMX',
#  'MTY',
#  'CD MX',
#  'cdmx',
#  'cancun',
#  'CACUN',
#  '  GDL  ',
#  'PUUEBLA',
#  'Puebla',
#  '  CDMX  ',
#  '  CANCUN  ',
#  'PUEBjA',
#  'GL',
#  'PUE',
#  '  MTY  ',
#  'gdl',
#  'MTY ',
#  'mty',
#  'puebla',
#  '  PUEBLA  ',
#  'GDL ',
#  'MY',
#  'Ciudad de Mexico',
#  'rUEBLA',
#  'MTYY',
#  'GGDL',
#  'UEBLA',
#  'MMTY',
#  'GDLL',
#  'Q.Roo',
#  'Monterrey',
#  'CDMMX',
#  'PUELA',
#  'Cancun',
#  'wDL',
#  'PUEBvA',
#  'Gdl',
#  'Mty',
#  'QRoo',
#  'PUEEBLA',
#  'CDzX',
#  'jDL',
#  'CCDMX',
#  'MONTERREY',
#  'PUEBL',
#  'PUEBLA ',
#  'DF',
#  'CDMXX',
#  'CDMg',
#  'CAN0UN',
#  'GUADALAJARA',
#  'MT',
#  'CDX',
#  'CAANCUN',
#  'CoMX',
#  'Cancún',
#  'CDwX',
#  'Cdmx',
#  'CDDMX',
#  'CANoUN',
#  'CIUDAD MEXICO',
#  'PUEB3A',
#  'Mty.',
#  'GD',
#  'CANCUNN',
#  '7TY',
#  'MkY',
#  'PUEBLLA',
#  'CANCU',
#  'Pue',
#  'CANCN',
#  'PnEBLA',
#  'C8MX',
#  'PUEBuA',
#  'CANCÚN',
#  'PPUEBLA',
#  'PUEB7A',
#  'PcEBLA',
#  'CaNCUN',
#  'M1Y',
#  'CCANCUN',
#  'G8L',
#  'DL',
#  'MTTY',
#  'Guadalajara',
#  'eDL',
#  'PEBLA',
#  'PUEBBLA',
#  'aDMX',
#  'PUEBdA',
#  'mDMX',
#  '0DL',
#  'CNCUN',
#  ' GDL',
#  'GoL',
#  'ANCUN',
#  '1ANCUN',
#  'C6NCUN',
#  'PoEBLA',
#  'DMX',
#  'PUEBLAA',
#  'McY',
#  'sTY',
#  'PUEBA',
#  '5DMX',
#  'CANCdN',
#  'CDM',
#  'CDlX',
#  'M9Y',
#  'TY',
#  'CDrX',
#  'CANCkN',
#  'CANaUN',
#  'wDMX',
#  'CANCUUN',
#  'CANjUN',
#  'MaY',
#  'PUEB8A',
#  'cUEBLA',
#  'CANiUN',
#  'GyL',
#  'GDDL',
#  'dTY',
#  'PUEBLa',
#  'CANCUn',
#  'qDL',
#  'CAoCUN',
#  'MTf',
#  'PrEBLA',
#  'PUjBLA',
#  'CMX',
#  'PUEaLA',
#  'P7EBLA',
#  'PqEBLA',
#  'CANC8N',
#  'CDvX',
#  'M8Y',
#  'GD0',
#  'CDMx',
#  'MT5',
#  'CANUN',
#  'PUErLA',
#  'MxY',
#  'CA7CUN',
#  'MT1',
#  'CANCuN',
#  'CiNCUN',
#  'CDgX',
#  'CD4X',
#  'CDcX',
#  'oDMX',
#  'PUBLA',
#  'CAqCUN',
#  'MTy',
#  'CqMX',
#  '6UEBLA',
#  'yDL',
#  'G6L',
#  'CAeCUN',
#  'zANCUN',
#  'PgEBLA',
#  'G7L',
#  'PUzBLA',
#  'MTr',
#  'MzY',
#  'GtL',
#  'GD8',
#  '3UEBLA',
#  'mANCUN',
#  'iTY',
#  'xDL',
#  'uTY',
#  'qTY',
#  'CyNCUN',
#  'CAsCUN',
#  'GDt',
#  'CANCCUN',
#  'CANpUN',
#  'gTY',
#  'tDL',
#  'jANCUN',
#  'CANCsN',
#  'CgNCUN',
#  'CsMX',
#  'CANNCUN',
#  'CDdX',
#  'CDMf',
#  'CANClN',
#  'kTY',
#  'MTg',
#  'GDo',
#  'vTY',
#  'PUEBL3',
#  'MTh',
#  'GpL',
#  'MTw',
#  'CDjX',
#  'CjMX',
#  'CAN3UN',
#  'hDMX',
#  'G0L',
#  'nTY',
#  'CsNCUN',
#  'GDy',
#  'yDMX',
#  'CANcUN',
#  'CANCzN',
#  'PfEBLA',
#  'PUEBL9',
#  '1TY',
#  'mTY',
#  'aDL',
#  'PUEoLA',
#  'PUoBLA',
#  'MTt',
#  'GbL',
#  'PUbBLA',
#  'PUsBLA',
#  'CANmUN',
#  'CA3CUN',
#  'PUgBLA',
#  'PhEBLA',
#  'tDMX',
#  'zDL',
#  'CA5CUN',
#  'CDMt',
#  'fDL',
#  'MTm',
#  'MTc',
#  'G9L',
#  'gDL',
#  'GlL',
#  'CDM1',
#  'CAnCUN',
#  'GdL',
#  'GDi',
#  'sANCUN',
#  '0ANCUN',
#  'PUEgLA',
#  'PUEBoA',
#  '2TY',
#  '3DL',
#  'sDMX',
#  'C2NCUN',
#  'MT7',
#  'CDsX',
#  'MT2',
#  'MtY',
#  'bDMX',
#  'PUEByA',
#  'jTY',
#  'CANCyN',
#  'CxMX',
#  'PUEtLA',
#  'PUEBmA',
#  'PUE8LA',
#  'tTY',
#  'CDM8',
#  'CANxUN',
#  'PUEfLA',
#  'CANCUz',
#  'MTj',
#  '9UEBLA',
#  'aTY',
#  'ChMX',
#  'CAN7UN',
#  '7UEBLA',
#  'PvEBLA',
#  'CDqX',
#  'CAN4UN',
#  'MgY',
#  '3ANCUN',
#  'PUE2LA',
#  'hDL',
#  'CDnX',
#  'oUEBLA',
#  'MiY',
#  'GiL',
#  '0UEBLA',
#  'PUEBhA',
#  'GDz',
#  'PUEyLA',
#  'PxEBLA',
#  'PUEB9A',
#  'CANfUN',
#  'wTY',
#  'P5EBLA',
#  'CDMi',
#  'CAuCUN',
#  'CANtUN',
#  'CbNCUN',
#  'jDMX',
#  '4DL',
#  'CA9CUN',
#  'MwY',
#  'PUExLA',
#  'M5Y',
#  'PUyBLA',
#  'CDhX',
#  'PUdBLA',
#  'CANCqN',
#  'MuY',
#  'aUEBLA',
#  'GDe',
#  'C0NCUN',
#  'CD1X',
#  'CApCUN',
#  'kUEBLA',
#  'GD2',
#  'CxNCUN',
#  'CD8X',
#  '0DMX',
#  'PjEBLA',
#  'qANCUN',
#  'uDL',
#  'CANkUN',
#  'CwNCUN',
#  'P9EBLA',
#  'iANCUN',
#  'CDMl',
#  'PUmBLA',
#  'PUEeLA',
#  'PUEzLA',
#  'GrL',
#  'PU0BLA',
#  'MTe',
#  'CnMX',
#  'MvY',
#  'GD7',
#  'G1L',
#  'CqNCUN',
#  'PU6BLA',
#  'yUEBLA',
#  'CANCU0',
#  'MbY',
#  'MTl',
#  'CDMn',
#  'MlY',
#  'CDtX',
#  'PUEwLA',
#  '9TY',
#  'CANCUa',
#  'oANCUN',
#  'CAhCUN',
#  'PU9BLA',
#  'CANCUg',
#  'C6MX',
#  'CAvCUN',
#  'GDs',
#  'eTY',
#  'C8NCUN',
#  'CvNCUN',
#  'PpEBLA',
#  'CANCUk',
#  'CANCwN',
#  'CDMk',
#  'CDMe',
#  '8UEBLA',
#  'PUEmLA',
#  'GDk',
#  'CDMy',
#  'P8EBLA',
#  'CANCU5',
#  'GDr',
#  '1DL',
#  'G5L',
#  'CAN2UN',
#  'CANC7N',
#  'lDMX',
#  'bTY',
#  'zUEBLA',
#  'CANCU9',
#  'CAN8UN',
#  'GD3',
#  'MTn',
#  'CAxCUN',
#  'PUhBLA',
#  'CANCUx',
#  'CANrUN',
#  'CANCU4',
#  'MTo',
#  '8DL',
#  'MTi',
#  'zTY',
#  'CDMa',
#  'MT3',
#  'CAN1UN',
#  'M0Y',
#  'C9MX',
#  'CANCbN',
#  'hTY',
#  '0TY',
#  'CD5X',
#  'CzMX',
#  'GDx',
#  'PU7BLA',
#  'GgL',
#  'CANCUw',
#  'CDMh',
#  'CAtCUN',
#  'GDa',
#  'MhY',
#  'CDM3',
#  'GD4',
#  'CANCUh',
#  'GuL',
#  'CaMX',
#  'GDq',
#  'hUEBLA',
#  'M3Y',
#  'MTd',
#  'GD6',
#  'PUEBiA',
#  'PkEBLA',
#  'yTY',
#  'CDMu',
#  'lDL',
#  'MTq',
#  'CDMs',
#  'PUEBqA',
#  'iUEBLA',
#  'PUEB1A',
#  'CANyUN',
#  'CDMr',
#  'CANCUf',
#  'pDMX',
#  'M2Y',
#  'PeEBLA',
#  'M7Y',
#  'CANCUp',
#  'PU5BLA',
#  'C7MX',
#  'MdY',
#  'PUEiLA',
#  'CAgCUN',
#  'PUEBkA',
#  'uANCUN',
#  'CANuUN',
#  'CD7X',
#  'CDxX',
#  'MT6',
#  'CANCtN',
#  'M6Y',
#  'CDiX',
#  'CdNCUN',
#  'CDMc',
#  'PUcBLA',
#  'CANgUN',
#  'MpY',
#  'GkL',
#  'GwL',
#  'CDMb',
#  'MoY',
#  '4TY',
#  'PUEBpA',
#  'PUeBLA',
#  'rDL',
#  'CANCpN',
#  'PUrBLA',
#  'CDoX',
#  'MTz',
#  'fDMX',
#  'fUEBLA',
#  'GDw',
#  'CDbX',
#  'PUEB5A',
#  'tUEBLA',
#  'MmY',
#  'lANCUN',
#  'PUEBLv',
#  'CmNCUN',
#  'fTY',
#  'vANCUN',
#  'PUqBLA',
#  'GhL',
#  'GnL',
#  'cANCUN',
#  'CrNCUN',
#  'CrMX',
#  'CDaX',
#  'CpNCUN',
#  'P4EBLA',
#  'PUEBLi',
#  'PUEBLd',
#  'CANCnN',
#  'PUEB6A',
#  'PUEBLq',
#  'CANCcN',
#  'jUEBLA',
#  'GDm',
#  '8DMX',
#  'PUEBrA',
#  'MT4',
#  'CANCUc',
#  'PUEBtA',
#  '6TY',
#  'G3L',
#  'CANwUN',
#  'PUEBLy',
#  'MsY',
#  'PUEBLs',
#  'PUEBLo',
#  'CAlCUN',
#  '2UEBLA',
#  'CANCU7',
#  'eUEBLA',
#  'MT9',
#  'iDL',
#  'CAmCUN',
#  'PUEBL1',
#  'CANCUl',
#  'CANCxN',
#  'ClMX',
#  'CANCgN',
#  'CDMv',
#  'PU4BLA',
#  'PUEBLm',
#  'bANCUN',
#  'C7NCUN',
#  'CDMw',
#  'GDv',
#  'bDL',
#  'CANCUt',
#  'CANCUb',
#  'PUEcLA',
#  '8TY',
#  'PUEB0A',
#  'vDL',
#  'dDL',
#  'CjNCUN',
#  'CDkX',
#  '9DL',
#  'PUEBLr',
#  'CAwCUN',
#  'CbMX',
#  'CyMX',
#  '7ANCUN',
#  'PUEBLw',
#  'CDeX',
#  'PUEBsA',
#  'CuMX',
#  'CANCU8',
#  'PU3BLA',
#  'CD0X',
#  'gANCUN',
#  'CDuX',
#  'GDp',
#  'CtMX',
#  'GDf',
#  'GqL',
#  'C5MX',
#  'GmL',
#  'G2L',
#  'sDL',
#  '4DMX',
#  'CANzUN',
#  'CtNCUN',
#  'CANCUs',
#  'CD9X',
#  'CgMX',
#  'CANCU2',
#  'PUEBL5',
#  'GDn',
#  '2DMX',
#  'MjY',
#  'PUxBLA',
#  'MTa',
#  'PUEnLA',
#  'nDL',
#  'G4L',
#  'GaL',
#  'CAjCUN',
#  'CANbUN',
#  'CANsUN',
#  'kANCUN',
#  'PUEBlA',
#  '6DL',
#  'CDmX',
#  'PzEBLA',
#  'GzL',
#  'PUEBL2',
#  'PUEsLA',
#  'CmMX',
#  'GcL',
#  'CAyCUN',
#  '5ANCUN',
#  'GjL',
#  'MTv',
#  'GeL',
#  'MTp',
#  'CAaCUN',
#  'PUEjLA',
#  'PUEBLk',
#  'CANCUr',
#  'PUE9LA',
#  'C3MX',
#  'PUfBLA',
#  'GDc',
#  'MfY',
#  'CDyX',
#  'CANCUj',
#  '3TY',
#  'CDMz',
#  'CD6X',
#  'PUpBLA',
#  'GsL',
#  'sUEBLA',
#  'PUE1LA',
#  'cDMX',
#  'PUEBLh',
#  'GD5',
#  'CA0CUN',
#  'PUkBLA',
#  'PU8BLA',
#  'PwEBLA',
#  'PUEdLA',
#  'GDu',
#  'pANCUN',
#  'PUEBLc',
#  'GDd',
#  'PUEBLn',
#  'aANCUN',
#  'PiEBLA',
#  'CANCaN',
#  'hANCUN',
#  'CeMX',
#  'GfL',
#  'wUEBLA',
#  'CAkCUN',
#  'CANCUd',
#  'GxL',
#  'C3NCUN',
#  'ClNCUN',
#  'PUE4LA',
#  'pDL',
#  'yANCUN',
#  'PUaBLA',
#  'CAdCUN',
#  '2DL',
#  'CkMX',
#  'fANCUN',
#  'PU1BLA',
#  'kDL',
#  'C4NCUN',
#  'CANCjN',
#  'PUEBnA',
#  'CdMX',
#  'dANCUN',
#  'CfMX',
#  '5UEBLA',
#  'PUEBzA',
#  'PtEBLA',
#  'CA2CUN',
#  'PUEBL0',
#  'CANCeN',
#  'bUEBLA',
#  'C2MX',
#  '5TY',
#  'mUEBLA',
#  'PUElLA',
#  'wANCUN',
#  'MT8',
#  'CArCUN',
#  'MqY',
#  'CANCUv',
#  'CDM4',
#  'CANCoN',
#  'CANCUu',
#  'PUvBLA',
#  'PUE5LA',
#  'gDMX',
#  'PUEBL6',
#  'GDb',
#  'CANCUm',
#  'CDM5',
#  'PUEBaA',
#  'CANC2N',
#  '5DL',
#  'CANC5N',
#  'CANCfN',
#  'C1MX',
#  'CAbCUN',
#  'MTs',
#  'PUnBLA',
#  'CAiCUN',
#  'PUlBLA',
#  'M4Y',
#  'CDMd',
#  'CcMX',
#  'mDL',
#  'C4MX',
#  'MTu',
#  'CD3X',
#  'zDMX',
#  'PUEBLb',
#  'CDMo',
#  'CDMj',
#  'CANChN',
#  'PUuBLA',
#  'CiMX',
#  'nUEBLA',
#  'PsEBLA',
#  'GvL',
#  'CANC0N',
#  'PUEhLA']
