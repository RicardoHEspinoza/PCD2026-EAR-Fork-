# %% [markdown]
# # Importar las librerias basicas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.ensemble import IsolationForest

# %% [markdown]
# # Abrir el archivo csv

# %%
df = pd.read_csv("../Datas/5. ciudades_normalizados_rellenado.csv", encoding="utf-8")
df.head()
# Out:
#    id_transaccion  id_producto              nombre_producto  id_tienda  \
# 0               1           63                 Salsa Bufalo          6
# 1               2           32                Agua Epura 1L          5
# 2               3           77         Cereal Choco Krispis          2
# 3               4           45  Mix de Nueces Member's Mark          7
# 4               5           42       Yoghurt Griego Yoplait          1
#
#   nombre_tienda categoria_tienda  ciudad       fecha  precio_normalizado  \
# 0   City Market          Premium  CANCUN  2025-10-27               23.10
# 1      Chedraui     Autoservicio  PUEBLA  2025-12-27                9.49
# 2    Sam's Club          Mayoreo  PUEBLA  2025-11-09               53.36
# 3      La Comer          Premium  CANCUN  2025-10-27               88.14
# 4       Walmart     Autoservicio     GDL  2025-09-03               28.32
#
#   ciudad_normalizada  mes
# 0             CANCUN   10
# 1             PUEBLA   12
# ...

# %%
df
# Out:
#          id_transaccion  id_producto              nombre_producto  id_tienda  \
# 0                     1           63                 Salsa Bufalo          6
# 1                     2           32                Agua Epura 1L          5
# 2                     3           77         Cereal Choco Krispis          2
# 3                     4           45  Mix de Nueces Member's Mark          7
# 4                     5           42       Yoghurt Griego Yoplait          1
# ...                 ...          ...                          ...        ...
# 1029995         1029996           90           Tortillas Tía Rosa          7
# 1029996         1029997          100         Detergente Ariel 1kg          3
# 1029997         1029998           42       Yoghurt Griego Yoplait          9
# 1029998         1029999           26                 Crema Alpura          6
# 1029999         1030000            2                  Pepsi 600ml          7
#
# ...

# %% [markdown]
# # Visualizacion de informacion

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030000 entries, 0 to 1029999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id_transaccion      1030000 non-null  int64
#  1   id_producto         1030000 non-null  int64
#  2   nombre_producto     1030000 non-null  object
#  3   id_tienda           1030000 non-null  int64
#  4   nombre_tienda       1030000 non-null  object
#  5   categoria_tienda    1030000 non-null  object
#  6   ciudad              1013246 non-null  object
#  7   fecha               1030000 non-null  object
#  8   precio_normalizado  1030000 non-null  float64
#  9   ciudad_normalizada  1013246 non-null  object
#  10  mes                 1030000 non-null  int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 86.4+ MB

# %%
df.isnull().sum()
# Out:
# id_transaccion            0
# id_producto               0
# nombre_producto           0
# id_tienda                 0
# nombre_tienda             0
# categoria_tienda          0
# ciudad                16754
# fecha                     0
# precio_normalizado        0
# ciudad_normalizada    16754
# mes                       0
# dtype: int64

# %% [markdown]
# # Este lo use para lograr ver los valores unicos y asi idenfitificar los errores

# %%
df["ciudad_normalizada"].unique()
# Out:
# array(['CANCUN', 'PUEBLA', 'GUADALAJARA', 'CDMX', 'MONTERREY', nan,
#        'QUINTANA ROO'], dtype=object)

# %%
df["ciudad_normalizada"].value_counts(dropna=False)

# %% [markdown]
# ## El error mas facil de remover era el de cambiar Quintana Roo por Cancun

# %%
df["ciudad_normalizada"] = df["ciudad_normalizada"].replace({
    "QUINTANA ROO": "CANCUN"
})

# %%
df["ciudad_normalizada"].value_counts(dropna=False)
# Out:
# ciudad_normalizada
# CDMX           203549
# PUEBLA         202511
# MONTERREY      202479
# GUADALAJARA    202380
# CANCUN         202327
# Name: count, dtype: int64

# %%
df = df.dropna(subset=["ciudad_normalizada"])

# %%
df = df.drop(columns=["ciudad"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df = df.drop(columns=["ciudad"])
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
for col in df.columns:
    print(f"\nColumna: {col}")
    print(df[col].unique())
# Out:
# Columna: id_transaccion
# [      1       2       3 ... 1029998 1029999 1030000]
#
# Columna: id_producto
# [ 63  32  77  45  42  72  85  53  78  36  23  76  37  10  18  94  19  59
#   75  35  29  58  60  82   7  87  51  50  17  91  22  49  65  39 100  95
#   56  97  70  44  21  25  34  33  16   2  57  31  40  52   8  55  90  98
#   38  61  43  30  41  11  62  96  81  68   1  27  88  13  47   3  24   5
#   99  86  12  28   6  67  69  74  71  80  26  89  83  48  54  93  84  15
#   64   4   9  46  20  66  92  14  73  79]
#
# Columna: nombre_producto
# ['Salsa Bufalo' 'Agua Epura 1L' 'Cereal Choco Krispis'
#  "Mix de Nueces Member's Mark" 'Yoghurt Griego Yoplait' 'Suero Electrolit'
#  'Cerveza Heineken' 'Cacahuates Hot Nuts' 'Cereal Froot Loops'
#  'Aceite Capullo' 'Chocolate Abuelita Tabletas' 'Cereal Cheerios'
#  'Mayonesa McCormick' 'Aceite Nutrioli 1L' 'Jugo del Valle Mango'
#  'Frijoles Bayos La Sierra' 'Refresco Fanta 600ml' 'Ron Bacardí Blanco'
# ...
